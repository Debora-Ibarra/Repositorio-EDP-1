# %% [markdown]
# <a href="https://colab.research.google.com/github/Debora-Ibarra/Repositorio-EDP-1/blob/main/Ejemplo_terminado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import numpy as np

x=np.linspace(-10,10,400)

y=x**2
plt.plot(x,y,label=r'$y=x^2')
plt.xlabel('x')
plt.ylabel('y')

plt.legend ()

plt.grid(True)
plt.show()
